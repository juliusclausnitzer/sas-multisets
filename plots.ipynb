# %%
import matplotlib.pyplot as plt

# Data for plotting
epochs = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_accuracy = [33.05, 39.24, 42.26, 45.29, 46.51, 47.33, 49.1, 49.82, 50.14, 51.06, 51.97, 52.28, 52.1, 53.64, 54.45, 53.98, 54.45, 54.45]

# Create the plot
plt.figure(figsize=(10, 6))
plt.plot(epochs, test_accuracy, marker='o', linestyle='-', color='b')
plt.title('Test Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy (%)')
plt.grid(True)
plt.xticks(epochs, rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for plotting
epochs = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_acc = [
    36.03, 41.36, 44.18, 46.66, 48.08, 
    49.49, 49.59, 50.59, 50.73, 51.15, 
    50.96, 52.4, 52.16, 52.44, 52.62, 
    51.94, 52.66, 52.26
]

# Creating the plot
plt.figure(figsize=(10, 5))
plt.plot(epochs, test_acc, label='Test Accuracy', color='b', marker='o')
plt.title('Test Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Test Accuracy (%)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for plotting for continuous SAS
epochs_continuous = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_accuracy_continuous = [33.05, 39.24, 42.26, 45.29, 46.51, 47.33, 49.1, 49.82, 50.14, 51.06, 51.97, 52.28, 52.1, 53.64, 54.45, 53.98, 54.45, 54.45]

# Data for plotting for normal SAS
epochs_normal = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_acc_normal = [
    36.03, 41.36, 44.18, 46.66, 48.08, 
    49.49, 49.59, 50.59, 50.73, 51.15, 
    50.96, 52.4, 52.16, 52.44, 52.62, 
    51.94, 52.66, 52.26
]

# Create the plot
plt.figure(figsize=(12, 7))
plt.plot(epochs_continuous, test_accuracy_continuous, marker='o', linestyle='-', color='red', label='Continuous SAS')
plt.plot(epochs_normal, test_acc_normal, marker='s', linestyle='--', color='blue', label='Standard SAS')
#plt.title('Test Accuracy Over Epochs for Continuous and Standard SAS')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy (%)')
plt.xticks(epochs_continuous, rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.savefig("SAS_epoch_0.2_resnet18.png")
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for Continuous SAS
epochs_continuous = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_accuracy_continuous = [33.05, 39.24, 42.26, 45.29, 46.51, 47.33, 49.1, 49.82, 50.14, 51.06, 51.97, 52.28, 52.1, 53.64, 54.45, 53.98, 54.45, 54.45]

# Data for Normal SAS
epochs_normal = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_acc_normal = [36.03, 41.36, 44.18, 46.66, 48.08, 49.49, 49.59, 50.59, 50.73, 51.15, 50.96, 52.4, 52.16, 52.44, 52.62, 51.94, 52.66, 52.26]

# Data for Random Subset Training
epochs_subset = [20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360]
test_acc_subset = [35.37, 39.57, 42.15, 43.81, 46.06, 47.56, 49.45, 49.91, 50.64, 51.07, 51.84, 52.01, 52.31, 52.01, 51.95, 52.31, 52.01, 52.24]

# Create the plot
plt.figure(figsize=(12, 7))
plt.plot(epochs_continuous, test_accuracy_continuous, marker='o', linestyle='-', color='red', label='Continuous SAS')
plt.plot(epochs_normal, test_acc_normal, marker='s', linestyle='--', color='blue', label='Normal SAS')
plt.plot(epochs_subset, test_acc_subset, marker='^', linestyle=':', color='green', label='Random Subset Training')
plt.title('Test Accuracy Over Epochs for Different SAS Methods')
plt.xlabel('Epoch')
plt.ylabel('Test Accuracy (%)')
plt.xticks(epochs_continuous, rotation=45)  # Rotate x-axis labels for better readability
plt.grid(True)
plt.legend()
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()
